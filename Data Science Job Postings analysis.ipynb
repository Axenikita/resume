# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns
import os

# %%
df = list()

# %%
#Interesting Task Ideas:
#Practice data cleaning techniques
#Analyze the most in-demand job titles for data science professionals.
#Identify the top companies hiring for data science positions.
#Determine the most common job locations for data science roles.
#Explore the relationship between job level and required skills.

# %%
job_postings = pd.read_csv(r"C:\Users\Nikita\Downloads\job_postings.csv\job_postings.csv", encoding="ISO-8859-1")
job_skills = pd.read_csv(r"C:\Users\Nikita\Downloads\job_skills.csv\job_skills.csv", encoding="ISO-8859-1")
job_summary = pd.read_csv(r"C:\Users\Nikita\Downloads\job_summary.csv\job_summary.csv", encoding="ISO-8859-1")

# %%
job_postings
# Out:
#                                                 job_link  \
# 0      https://www.linkedin.com/jobs/view/senior-mach...
# 1      https://www.linkedin.com/jobs/view/principal-s...
# 2      https://www.linkedin.com/jobs/view/senior-etl-...
# 3      https://www.linkedin.com/jobs/view/senior-data...
# 4      https://www.linkedin.com/jobs/view/lead-data-e...
# ...                                                  ...
# 12212  https://uk.linkedin.com/jobs/view/data-reporti...
# 12213  https://www.linkedin.com/jobs/view/corporate-a...
# 12214  https://www.linkedin.com/jobs/view/senior-data...
# 12215  https://www.linkedin.com/jobs/view/senior-data...
# 12216  https://www.linkedin.com/jobs/view/medical-tec...
#
#                  last_processed_time   last_status got_summary got_ner  \
# 0      2024-01-21 08:08:48.031964+00  Finished NER           t       t
# 1      2024-01-20 04:02:12.331406+00  Finished NER           t       t
# ...

# %%
job_skills
# Out:
#                                                 job_link  \
# 0      https://www.linkedin.com/jobs/view/senior-mach...
# 1      https://www.linkedin.com/jobs/view/principal-s...
# 2      https://www.linkedin.com/jobs/view/senior-etl-...
# 3      https://www.linkedin.com/jobs/view/senior-data...
# 4      https://www.linkedin.com/jobs/view/lead-data-e...
# ...                                                  ...
# 12212  https://uk.linkedin.com/jobs/view/data-reporti...
# 12213  https://www.linkedin.com/jobs/view/corporate-a...
# 12214  https://www.linkedin.com/jobs/view/senior-data...
# 12215  https://www.linkedin.com/jobs/view/senior-data...
# 12216  https://www.linkedin.com/jobs/view/medical-tec...
#
#                                               job_skills
# 0      Machine Learning, Programming, Python, Scala, ...
# 1      C++, Python, PyTorch, TensorFlow, MXNet, CUDA,...
# 2      ETL, Data Integration, Data Transformation, Da...
# ...

# %%
job_summary
# Out:
#                                                 job_link  \
# 0      https://www.linkedin.com/jobs/view/senior-mach...
# 1      https://www.linkedin.com/jobs/view/principal-s...
# 2      https://www.linkedin.com/jobs/view/senior-etl-...
# 3      https://www.linkedin.com/jobs/view/senior-data...
# 4      https://www.linkedin.com/jobs/view/lead-data-e...
# ...                                                  ...
# 12212  https://uk.linkedin.com/jobs/view/data-reporti...
# 12213  https://www.linkedin.com/jobs/view/corporate-a...
# 12214  https://www.linkedin.com/jobs/view/senior-data...
# 12215  https://www.linkedin.com/jobs/view/senior-data...
# 12216  https://www.linkedin.com/jobs/view/medical-tec...
#
#                                              job_summary
# 0      Company Description\nJobs for Humanity is part...
# 1      Who We Are\nAurora (Nasdaq: AUR) is delivering...
# 2      Location: New York City, NY\nPosition Summary\...
# ...

# %%
job_skills.dropna()
# Out:
#                                                 job_link  \
# 0      https://www.linkedin.com/jobs/view/senior-mach...
# 1      https://www.linkedin.com/jobs/view/principal-s...
# 2      https://www.linkedin.com/jobs/view/senior-etl-...
# 3      https://www.linkedin.com/jobs/view/senior-data...
# 4      https://www.linkedin.com/jobs/view/lead-data-e...
# ...                                                  ...
# 12212  https://uk.linkedin.com/jobs/view/data-reporti...
# 12213  https://www.linkedin.com/jobs/view/corporate-a...
# 12214  https://www.linkedin.com/jobs/view/senior-data...
# 12215  https://www.linkedin.com/jobs/view/senior-data...
# 12216  https://www.linkedin.com/jobs/view/medical-tec...
#
#                                               job_skills
# 0      Machine Learning, Programming, Python, Scala, ...
# 1      C++, Python, PyTorch, TensorFlow, MXNet, CUDA,...
# 2      ETL, Data Integration, Data Transformation, Da...
# ...

# %%
job_skills['job_skills'] = job_skills['job_skills'].astype(str)
job_skills['skill_count'] = job_skills['job_skills'].str.split(', ').apply(len)
job_skills
# Out:
#                                                 job_link  \
# 0      https://www.linkedin.com/jobs/view/senior-mach...
# 1      https://www.linkedin.com/jobs/view/principal-s...
# 2      https://www.linkedin.com/jobs/view/senior-etl-...
# 3      https://www.linkedin.com/jobs/view/senior-data...
# 4      https://www.linkedin.com/jobs/view/lead-data-e...
# ...                                                  ...
# 12212  https://uk.linkedin.com/jobs/view/data-reporti...
# 12213  https://www.linkedin.com/jobs/view/corporate-a...
# 12214  https://www.linkedin.com/jobs/view/senior-data...
# 12215  https://www.linkedin.com/jobs/view/senior-data...
# 12216  https://www.linkedin.com/jobs/view/medical-tec...
#
#                                               job_skills  skill_count
# 0      Machine Learning, Programming, Python, Scala, ...           27
# 1      C++, Python, PyTorch, TensorFlow, MXNet, CUDA,...           23
# ...

# %%
skills = ''
for skill in job_skills.job_skills:
    skills += skill

# %%
skills = skills.split(', ')
skills[:10]
# Out:
# ['Machine Learning',
#  'Programming',
#  'Python',
#  'Scala',
#  'Java',
#  'Data Engineering',
#  'Distributed Computing',
#  'Statistical Modeling',
#  'Optimization',
#  'Data Pipelines']

# %%
from collections import Counter
counts = Counter(skills)    
common_skills = counts.most_common(15)
common_skills
# Out:
# [('Python', 4393),
#  ('SQL', 4216),
#  ('Communication', 2421),
#  ('Tableau', 1624),
#  ('AWS', 1615),
#  ('Data Visualization', 1508),
#  ('R', 1503),
#  ('Data Analysis', 1480),
#  ('Machine Learning', 1399),
#  ('Spark', 1369),
#  ('Java', 1217),
#  ('Teamwork', 1162),
#  ('Project Management', 1091),
#  ('Problem Solving', 1058),
#  ('Hadoop', 1044)]

# %%
labels, values = zip(*common_skills)
plt.figure(figsize=(12, 8))
plt.barh(labels[::-1], values[::-1], color=sns.color_palette("Spectral"))

plt.xlabel('Frequency')
plt.ylabel('Skills')
plt.title('Top 15 Skills')

plt.show()

# %%
print(f"You need on average {job_skills.skill_count.median()} skills to apply for a job in data science")
# Out:
# You need on average 24.0 skills to apply for a job in data science

# %%
data_science_jobs = job_postings[job_postings['job_title'].str.contains('Data Scientist|Data Analyst|Machine Learning Engineer|Data Engineer|Analyst|Data', case=False)]

# %%
data_science_jobs
# Out:
#                                                 job_link  \
# 0      https://www.linkedin.com/jobs/view/senior-mach...
# 2      https://www.linkedin.com/jobs/view/senior-etl-...
# 3      https://www.linkedin.com/jobs/view/senior-data...
# 4      https://www.linkedin.com/jobs/view/lead-data-e...
# 5      https://www.linkedin.com/jobs/view/senior-data...
# ...                                                  ...
# 12210  https://www.linkedin.com/jobs/view/data-entry-...
# 12211  https://ca.linkedin.com/jobs/view/senior-data-...
# 12212  https://uk.linkedin.com/jobs/view/data-reporti...
# 12214  https://www.linkedin.com/jobs/view/senior-data...
# 12215  https://www.linkedin.com/jobs/view/senior-data...
#
#                  last_processed_time   last_status got_summary got_ner  \
# 0      2024-01-21 08:08:48.031964+00  Finished NER           t       t
# 2      2024-01-21 08:08:31.941595+00  Finished NER           t       t
# ...

# %%
from collections import Counter
counts = Counter(data_science_jobs.job_title)    
common_job_title = counts.most_common(15)
common_job_title
# Out:
# [('Senior Data Engineer', 285),
#  ('Senior Data Analyst', 163),
#  ('Data Engineer', 149),
#  ('Data Analyst', 137),
#  ('Data Scientist', 128),
#  ('Lead Data Engineer', 123),
#  ('Senior Data Scientist', 119),
#  ('Data Architect', 111),
#  ('Staff Machine Learning Engineer, Series A', 101),
#  ('Senior Machine Learning Engineer', 59),
#  ('Manager, Data Loss Prevention (DLP) Engineer (Symantec)', 57),
#  ('Manager, Data Engineering', 57),
#  ('Principal Associate, Data Loss Prevention (DLP) Engineer', 53),
#  ('Senior Data Engineer, Public Company', 53),
#  ('Senior Machine Learning Engineer - AI', 53)]

# %%
labels, values = zip(*common_job_title)
plt.figure(figsize=(12, 8))
plt.barh(labels[::-1], values[::-1], color=sns.color_palette("Spectral"))

plt.xlabel('Frequency')
plt.ylabel('job titles')
plt.title('Top 15 job title')

plt.show()

# %%
labels, values = zip(*common_job_title)
plt.figure(figsize=(12, 8))
bars = plt.bar(labels[::-1], values[::-1], color=sns.color_palette("Spectral"))

for bar, value in zip(bars, values[::-1]):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(value), 
             va='bottom', ha='center', fontsize=10)

plt.xlabel('Job Titles')
plt.ylabel('Frequency')
plt.title('Top 15 Job Titles')

plt.xticks(rotation=45, ha='right')

plt.tight_layout()

plt.show()

# %%
labels, values = zip(*common_job_title)
plt.figure(figsize=(8, 8))
plt.pie(values[::-1], labels=labels[::-1], autopct='%1.1f%%', startangle=140, colors=sns.color_palette("Spectral"))
plt.axis('equal')  # Чтобы диаграмма выглядела как круг, а не эллипс
plt.title('Share of top 15 company for datascience', pad=40)

plt.show()

# %%
counts = Counter(data_science_jobs.company)    
common_company_for_datascience = counts.most_common(15)
common_company_for_datascience
# Out:
# [('Jobs for Humanity', 685),
#  ('Recruiting from Scratch', 209),
#  ('Dice', 186),
#  ('ClearanceJobs', 161),
#  ('Agoda', 154),
#  ('ClickJobs.io', 131),
#  ('Capital One', 85),
#  ('Amazon Web Services (AWS)', 68),
#  ('Deloitte', 67),
#  ('ACV Auctions', 58),
#  ('Steneral Consulting', 53),
#  ('Energy Jobline', 51),
#  ('Bank of America', 48),
#  ('Walmart', 43),
#  ('Harnham', 41)]

# %%
labels, values = zip(*common_company_for_datascience)
plt.figure(figsize=(12, 8))
bars = plt.barh(labels[::-1], values[::-1], color=sns.color_palette("Spectral"))

# Добавляем значения над столбцами
for bar, value in zip(bars, values[::-1]):
    plt.text(bar.get_width(), bar.get_y() + bar.get_height() / 2, str(value), 
             va='center', ha='left', fontsize=12)

plt.xlabel('Frequency')
plt.ylabel('Companies')
plt.title('Top Companies Hiring for Data Science Positions')

plt.tight_layout()  # Для более компактного отображения

plt.show()

# %%
labels, values = zip(*common_company_for_datascience)
plt.figure(figsize=(8, 8))
plt.pie(values[::-1], labels=labels[::-1], autopct='%1.1f%%', startangle=140, colors=sns.color_palette("Spectral"))
plt.axis('equal')

plt.title('Share of top 15 company for datascience', pad=20) 

plt.show()

# %%
counts = Counter(data_science_jobs.search_city)    
common_job_location = counts.most_common(15)
common_job_location
# Out:
# [('Greater London', 163),
#  ('Austin', 151),
#  ('Garland', 126),
#  ('Santa Clara', 123),
#  ('Baytown', 112),
#  ('Eastchester', 104),
#  ('Bound Brook', 102),
#  ('Chicago', 101),
#  ('Summit', 95),
#  ('Manassas', 94),
#  ('Montpelier', 91),
#  ('Alexandria', 90),
#  ('Novato', 90),
#  ('Norristown', 85),
#  ('Beverly', 82)]

# %%
labels, values = zip(*common_job_location)
plt.figure(figsize=(12, 8))
bars = plt.barh(labels[::-1], values[::-1], color=sns.color_palette("Spectral"))

# Добавляем значения над столбцами
for bar, value in zip(bars, values[::-1]):
    plt.text(bar.get_width(), bar.get_y() + bar.get_height() / 2, str(value), 
             va='center', ha='left', fontsize=12)

plt.xlabel('Frequency')
plt.ylabel('City')
plt.title('Top 15 location for Data Science Positions')

plt.tight_layout() 

plt.show()

# %%
import geopy
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="geoapiExercises")

coordinates = {}

for location in labels[::-1]:
    location = location.strip()
    location_key = location.lower() 
    location_coordinates = geolocator.geocode(location)
    
    if location_coordinates:
        coordinates[location_key] = (location_coordinates.latitude, location_coordinates.longitude)


map_data_science = folium.Map(location=[0, 0], zoom_start=2)

for location, count in zip(labels[::-1], values[::-1]):
    location = location.strip().lower() 
    if location in coordinates:
        folium.Marker(location=coordinates[location], popup=f'{location}: {count}').add_to(map_data_science)
        
map_data_science
# Out:
# ---------------------------------------------------------------------------
# AdapterHTTPError                          Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\geopy\geocoders\base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     367 if is_json:
# --> 368     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369 else:
#
# File ~\anaconda3\lib\site-packages\geopy\adapters.py:472, in RequestsAdapter.get_json(self, url, timeout, headers)
#     471 def get_json(self, url, *, timeout, headers):
# --> 472     resp = self._request(url, timeout=timeout, headers=headers)
#     473     try:
#
# File ~\anaconda3\lib\site-packages\geopy\adapters.py:500, in RequestsAdapter._request(self, url, timeout, headers)
#     499     if resp.status_code >= 400:
# --> 500         raise AdapterHTTPError(
#     501             "Non-successful status code %s" % resp.status_code,
# ...

# %%
job_skills['job_skills'] = job_skills['job_skills'].str.split(', ')
job_skills_expanded = job_skills.explode('job_skills')
job_skills_expanded
# Out:
#                                                 job_link  \
# 0      https://www.linkedin.com/jobs/view/senior-mach...
# 0      https://www.linkedin.com/jobs/view/senior-mach...
# 0      https://www.linkedin.com/jobs/view/senior-mach...
# 0      https://www.linkedin.com/jobs/view/senior-mach...
# 0      https://www.linkedin.com/jobs/view/senior-mach...
# ...                                                  ...
# 12216  https://www.linkedin.com/jobs/view/medical-tec...
# 12216  https://www.linkedin.com/jobs/view/medical-tec...
# 12216  https://www.linkedin.com/jobs/view/medical-tec...
# 12216  https://www.linkedin.com/jobs/view/medical-tec...
# 12216  https://www.linkedin.com/jobs/view/medical-tec...
#
#                                       job_skills  skill_count
# 0                               Machine Learning           27
# 0                                    Programming           27
# 0                                         Python           27
# ...

# %%
job_postings_skills = pd.merge(job_postings, job_skills_expanded, on='job_link', how='left')
job_postings_skills
# Out:
#                                                  job_link  \
# 0       https://www.linkedin.com/jobs/view/senior-mach...
# 1       https://www.linkedin.com/jobs/view/senior-mach...
# 2       https://www.linkedin.com/jobs/view/senior-mach...
# 3       https://www.linkedin.com/jobs/view/senior-mach...
# 4       https://www.linkedin.com/jobs/view/senior-mach...
# ...                                                   ...
# 314950  https://www.linkedin.com/jobs/view/medical-tec...
# 314951  https://www.linkedin.com/jobs/view/medical-tec...
# 314952  https://www.linkedin.com/jobs/view/medical-tec...
# 314953  https://www.linkedin.com/jobs/view/medical-tec...
# 314954  https://www.linkedin.com/jobs/view/medical-tec...
#
#                   last_processed_time   last_status got_summary got_ner  \
# 0       2024-01-21 08:08:48.031964+00  Finished NER           t       t
# 1       2024-01-21 08:08:48.031964+00  Finished NER           t       t
# ...

# %%
# Группируем данные по 'job_level'
grouped_by_level = job_postings_skills.groupby('job_level')

# Создаем пустой DataFrame для хранения результатов
top_skills_by_level = pd.DataFrame(columns=['job_level', 'job_skill', 'skill_count'])

for name, group in grouped_by_level:
    # Считаем количество встречаемости каждого навыка
    skills_counts = group['job_skills'].explode().value_counts()
    
    # Выбираем топ 15 навыков для данной группы
    top_skills = skills_counts.head(15)
    
    # Добавляем результаты в DataFrame
    for skill, count in top_skills.items():
        top_skills_by_level = top_skills_by_level.append({'job_level': name, 'job_skill': skill, 'skill_count': count}, ignore_index=True)

# Выводим результат
print(top_skills_by_level)
# Out:
#      job_level             job_skill skill_count
# 0    Associate                   SQL         462
# 1    Associate                Python         399
# 2    Associate         Communication         289
# 3    Associate         Data Analysis         282
# 4    Associate               Tableau         208
# 5    Associate    Data Visualization         177
# 6    Associate      Machine Learning         162
# 7    Associate                     R         160
# 8    Associate              Teamwork         155
# 9    Associate         Data analysis         146
# 10   Associate                 Excel         132
# 11   Associate          Data Science         127
# 12   Associate       Data Management         124
# 13   Associate       Troubleshooting         121
# 14   Associate  Communication Skills         119
# 15  Mid senior                Python        4402
# 16  Mid senior                   SQL        4144
# 17  Mid senior         Communication        2209
# ...

# %%
top_skills_by_level
# Out:
#      job_level             job_skill skill_count
# 0    Associate                   SQL         462
# 1    Associate                Python         399
# 2    Associate         Communication         289
# 3    Associate         Data Analysis         282
# 4    Associate               Tableau         208
# 5    Associate    Data Visualization         177
# 6    Associate      Machine Learning         162
# 7    Associate                     R         160
# 8    Associate              Teamwork         155
# 9    Associate         Data analysis         146
# 10   Associate                 Excel         132
# 11   Associate          Data Science         127
# 12   Associate       Data Management         124
# 13   Associate       Troubleshooting         121
# 14   Associate  Communication Skills         119
# 15  Mid senior                Python        4402
# 16  Mid senior                   SQL        4144
# 17  Mid senior         Communication        2209
# ...

# %%
for level in job_levels:
    # Фильтруем данные по текущему уровню работы
    level_data = top_skills_by_level[top_skills_by_level['job_level'] == level]
    
    # Создаем подходящий размер графика
    plt.figure(figsize=(20, 15))
    
    # Визуализируем данные для текущего уровня работы
    plt.barh(level_data['job_skill'], level_data['skill_count'], color='skyblue')
    
    # Увеличиваем размер оси Y
    plt.yticks(fontsize=14)
    
    # Добавляем названия осей и подробный заголовок
    plt.xlabel('Skill Count', fontsize=16)
    plt.ylabel('Job Skill', fontsize=20)  # Увеличиваем размер оси Y
    plt.title(f'Top Skills for Job Level: {level} (Total Skills: {len(level_data)})', fontsize=20)
    
    # Добавляем метки данных к каждому столбцу
    for index, value in enumerate(level_data['skill_count']):
        plt.text(value, index, str(value), fontsize=14)
    
    # Показываем график
    plt.show()

# %%
job_postings_skills_data_science = job_postings_skills[job_postings_skills['job_title'].str.contains('Data Scientist|Data Analyst|Machine Learning Engineer|Data Engineer|Analyst|Data', case=False)]
